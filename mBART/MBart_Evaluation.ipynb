# %% [markdown]
# <a href="https://colab.research.google.com/github/leonrafael29/W266_Final_Project/blob/main/mBART/MBart_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install requirements

# %%
# !pip install datasets -q
# !pip install sentencepiece -q
# !pip install transformers -q
# !pip install git+https://github.com/google-research/bleurt.git -q

# !wget -N https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip . -q
# !unzip -q -n BLEURT-20.zip
# Out:
#      |████████████████████████████████| 451 kB 4.2 MB/s
#      |████████████████████████████████| 212 kB 69.0 MB/s
#      |████████████████████████████████| 115 kB 94.4 MB/s
#      |████████████████████████████████| 182 kB 84.5 MB/s
#      |████████████████████████████████| 127 kB 89.2 MB/s
#      |████████████████████████████████| 1.3 MB 4.1 MB/s
#      |████████████████████████████████| 5.5 MB 4.2 MB/s
#      |████████████████████████████████| 7.6 MB 76.7 MB/s
#      |████████████████████████████████| 352 kB 4.2 MB/s
#   Building wheel for BLEURT (setup.py) ... done

# %% [markdown]
# Imports

# %%
import csv
import numpy as np
import pandas as pd
import torch
from bleurt import score
from datasets import load_dataset
from transformers import MBartForConditionalGeneration, \
    MBart50TokenizerFast, MBartConfig,\
    TrainingArguments, Trainer

# %% [markdown]
# Mount google drive to use for file saving and loading

# %%
from google.colab import files, drive
drive.mount('/content/gdrive/', force_remount=True)
# %cd gdrive/MyDrive
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/MyDrive

# %% [markdown]
# Global variables

# %%
ORIGINAL_MODEL_CHECKPOINT = 'facebook/mbart-large-50-many-to-many-mmt'
MODEL_CHECKPOINT = 'Mbart/Model/Tiny/epoch-1'
PAIRS = [
    'en-zh',
    'zh-en',
    'en-es',
    'es-zh',
    'es-en',
    'zh-es',
    ]
MBART_DATA = {
    'en-zh': {
        'size': 69020,
        'train': 48444,
        'val': 10381,
        'src': 'en',
        'tgt': 'zh',
        'src_tkn': 'en_XX',
        'tgt_tkn':'zh_CN',
        'tkn': 'zh_CN',
        'reverse': False,
        'train_path':f'Mbart/Data/en-zh-train_pairs.csv',
        'val_path':f'Mbart/Data/en-zh-val_pairs.csv',
        'test_path':f'Mbart/Data/en-zh-test_pairs.csv',
        },
    'zh-en': {
        'size': 69020,
        'train': 48444,
        'val': 10381,
        'src': 'zh',
        'tgt': 'en',
        'src_tkn': 'zh_CN',
        'tgt_tkn':'en_ZZ',
        'tkn': 'en_XX',
        'reverse': True,
        'train_path':f'Mbart/Data/en-zh-train_pairs.csv',
        'val_path':f'Mbart/Data/en-zh-val_pairs.csv',
        'test_path':f'Mbart/Data/en-zh-test_pairs.csv',
        },
    'en-es': {
        'size': 238511,
        'train': 167210,
        'val': 35831,
        'src': 'en',
        'tgt': 'es',
        'src_tkn': 'en_XX',
        'tgt_tkn':'es_XX',
        'tkn': 'es_XX',
        'reverse': False,
        'train_path':f'Mbart/Data/en-es-train_pairs.csv',
        'val_path':f'Mbart/Data/en-es-val_pairs.csv',
        'test_path':f'Mbart/Data/en-es-test_pairs.csv',
        },
    'es-zh': {
        'size': 65408,
        'train': 45796,
        'val': 9814,
        'src': 'es',
        'tgt': 'zh',
        'src_tkn': 'es_XX',
        'tgt_tkn':'zh_CN',
        'tkn': 'zh_CN',
        'reverse': False,
        'train_path':f'Mbart/Data/es-zh-train_pairs.csv',
        'val_path':f'Mbart/Data/es-zh-val_pairs.csv',
        'test_path':f'Mbart/Data/es-zh-test_pairs.csv',
        },
    'es-en': {
        'size': 238511,
        'train': 167210,
        'val': 35831,
        'src': 'es',
        'tgt': 'en',
        'src_tkn': 'es_XX',
        'tgt_tkn':'en_XX',
        'tkn': 'en_XX',
        'reverse': True,
        'train_path':f'Mbart/Data/en-es-train_pairs.csv',
        'val_path':f'Mbart/Data/en-es-val_pairs.csv',
        'test_path':f'Mbart/Data/en-es-test_pairs.csv',
        },
    'zh-es': {
        'size': 65408,
        'train': 45796,
        'val': 9814,
        'src': 'zh',
        'tgt': 'es',
        'src_tkn': 'zh_CN',
        'tgt_tkn':'es_XX',
        'tkn': 'es_XX',
        'reverse': True,
        'train_path':f'Mbart/Data/es-zh-train_pairs.csv',
        'val_path':f'Mbart/Data/es-zh-val_pairs.csv',
        'test_path':f'Mbart/Data/es-zh-test_pairs.csv',
        },
    }

DATASET = 'news_commentary'
MAX_LENGTH = 50
MAX_NEW_TOKENS = 50
TRUNCATION = True
PADDING = True
RETURN_TENSORS = 'pt'
BLEURT_CHECKPOINT = './BLEURT-20-D3'
N_EXAMPLES = 100

# %env PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:256
# Out:
# env: PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:256

# %% [markdown]
# Load Model, Metrics and Tokenizer

# %%
# Load the metrics model and tokenizer for use in the next cell

bleurt_metric = score.LengthBatchingBleurtScorer(BLEURT_CHECKPOINT)
#model = MBartForConditionalGeneration.from_pretrained(ORIGINAL_MODEL_CHECKPOINT)#, config=config)
tokenizer = MBart50TokenizerFast.from_pretrained(ORIGINAL_MODEL_CHECKPOINT)
model = torch.load('Mbart/Model/Tiny/epoch-1')
# Out:
# Downloading:   0%|          | 0.00/529 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/649 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.43k [00:00<?, ?B/s]

# %%
def eval_token(src_data, tokenizer, src_tkn):
  tokenizer.src_lang = src_tkn
 
  inputs = tokenizer(
        text=src_data,
        max_length=MAX_LENGTH,
        padding='max_length',
        truncation=TRUNCATION,
        return_tensors=RETURN_TENSORS,
        )

  return {'input_ids':inputs['input_ids'].cuda(),
          'attention_mask':inputs['attention_mask'].cuda()}

# %%
model.to('cuda')
# Out:
# MBartForConditionalGeneration(
#   (model): MBartModel(
#     (shared): Embedding(250054, 1024, padding_idx=1)
#     (encoder): MBartEncoder(
#       (embed_tokens): Embedding(250054, 1024, padding_idx=1)
#       (embed_positions): MBartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0): MBartEncoderLayer(
#           (self_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): MBartEncoderLayer(
#           (self_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): MBartEncoderLayer(
#           (self_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): MBartDecoder(
#       (embed_tokens): Embedding(250054, 1024, padding_idx=1)
#       (embed_positions): MBartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0): MBartDecoderLayer(
#           (self_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): MBartDecoderLayer(
#           (self_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): MBartDecoderLayer(
#           (self_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MBartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=250054, bias=False)
# )

# %% [markdown]
# Scoring function definition

# %%
# Function to generate dataset stream, select first n samples, generate predictions and return score and n samples used


def score_dataset(
    pair_index=0,
    starting_iter=0,
    end_iter=9999,
    n_examples=N_EXAMPLES,
    dataset=DATASET,
    model=model,
    tokenizer=tokenizer,
    bleurt_metric=bleurt_metric,
):
    """
    Evaluate the model that is passed into the function's performance on BLEU and
    BLEURT Translation performance. All results are output into csvs to store history
    external from the notebook.

    Inputs:
      Language Pair,
      Iteration Progress
      Ending Iteration,
      Number of examples
      Dataset
      Tokenizer
      Model,
      Bleurt Scorer

    Returns:
      Nothing

    """

    # Pair and properties for gatekeeping
    pair = PAIRS[pair_index]
    src = MBART_DATA[PAIRS[pair_index]]["src"]
    tgt = MBART_DATA[PAIRS[pair_index]]["tgt"]
    src_tkn = MBART_DATA[PAIRS[pair_index]]["src_tkn"]
    tgt_tkn = MBART_DATA[PAIRS[pair_index]]["tgt_tkn"]
    tkn = MBART_DATA[PAIRS[pair_index]]["tkn"]
    size = MBART_DATA[PAIRS[pair_index]]["size"]
    reverse = MBART_DATA[PAIRS[pair_index]]["reverse"]
    val = MBART_DATA[PAIRS[pair_index]]["val"]

    # Set Tokenizer up
    tokenizer.src_lang = src_tkn
    tokenizer.tgt_lang = tgt_tkn

    # Specify the scoring portion of the dataset
    eval = size * 0.15

    if eval > 10000:
      eval = 10000
    else:
      eval = 5000

    loops = int(eval // n_examples) - starting_iter + 1
    prev_iter = 0

    # Check where to start
    if starting_iter > 0:
        prev_iter = starting_iter

    # Check where to stop
    if end_iter == 9999:
        end_iter = loops
    else:
        loops = end_iter - starting_iter

    # Check if pair is reversed or not in the dataset loading
    if reverse:
        data_stream = load_dataset(DATASET, f"{tgt}-{src}", streaming=True)
    else:
        data_stream = load_dataset(DATASET, f"{src}-{tgt}", streaming=True)

    # Create/start your entries
    with open(f"Mbart/Tiny_e1_bleurt.csv", "a", newline="") as bluert_file:
        wr = csv.writer(bluert_file, quoting=csv.QUOTE_ALL)
        wr.writerow([f"starting tiny epoch_1_iter {prev_iter} ending at {end_iter}"])

    # Loop of scoring
    for run in range(loops + 1):
        start = prev_iter * n_examples

        # Normal loops of n_examples
        score_set = data_stream["train"].skip(start).take(n_examples)

        # Vectorize sentences
        src_data = [p["translation"][src] for p in score_set]
        tgt_data = [p["translation"][tgt] for p in score_set]

        # Progress text
        print(f"Now scoring iteration {run} of {loops}.")

        # Prepare inputs
        inputs = eval_token(src_data,tokenizer,src_tkn)

        # Pass inputs through the model
        generated_tokens = model.generate(
            **inputs,
            forced_bos_token_id=tokenizer.lang_code_to_id[tkn],
            max_new_tokens=MAX_NEW_TOKENS,
        )
        gen = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

        bleurt_score = bleurt_metric.score(references=tgt_data, candidates=gen)

        with open(f"Mbart/Tiny_e1_bleurt.csv","a", newline="") as bleurt_file:
            wr = csv.writer(bleurt_file, quoting=csv.QUOTE_ALL)
            wr.writerow([pair, run, np.mean(bleurt_score)])
        print(prev_iter+1, np.mean(bleurt_score))

        prev_iter += 1

    return None

# %% [markdown]
# Score the dataset

# %%
# Load individual dataset, score BLEU and BLEURT scores for dataset
for p in range(0, len(PAIRS)):
    print(f"Evaluating translation {PAIRS[p]}")
    score_dataset(
        pair_index=p,
        starting_iter=0,
        end_iter=9999,
        n_examples=N_EXAMPLES,
        dataset=DATASET,
        model=model,
        tokenizer=tokenizer,
        bleurt_metric=bleurt_metric,
    )
# Out:
# Evaluating translation en-zh
# Downloading builder script:   0%|          | 0.00/5.36k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/116k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Now scoring iteration 0 of 101.
# 1 0.2399071104824543
# Now scoring iteration 1 of 101.
# 2 0.2192081568390131
# Now scoring iteration 2 of 101.
# 3 0.22437858782708645
# Now scoring iteration 3 of 101.
# 4 0.23636277705430986
# Now scoring iteration 4 of 101.
# 5 0.26452936448156833
# Now scoring iteration 5 of 101.
# 6 0.20898724481463432
# Now scoring iteration 6 of 101.
# 7 0.2312250419706106
# Now scoring iteration 7 of 101.
# 8 0.23323311381042003
# Now scoring iteration 8 of 101.
# 9 0.20888338290154934
# Now scoring iteration 9 of 101.
# 10 0.230626600459218
# Now scoring iteration 10 of 101.
# 11 0.22267891220748426
# Now scoring iteration 11 of 101.
# 12 0.24702425062656402
# Now scoring iteration 12 of 101.
# 13 0.2527615723013878
# Now scoring iteration 13 of 101.
# 14 0.23696478344500066
# Now scoring iteration 14 of 101.
# 15 0.19910964407026768
# Now scoring iteration 15 of 101.
# 16 0.1965870313346386
# Now scoring iteration 16 of 101.
# 17 0.2110183569788933
# Now scoring iteration 17 of 101.
# 18 0.23797212786972521
# Now scoring iteration 18 of 101.
# 19 0.24464061751961708
# Now scoring iteration 19 of 101.
# 20 0.23121749326586724
# Now scoring iteration 20 of 101.
# 21 0.23241992577910423
# Now scoring iteration 21 of 101.
# 22 0.24064927525818347
# Now scoring iteration 22 of 101.
# 23 0.23445072814822196
# Now scoring iteration 23 of 101.
# 24 0.23336102470755576
# Now scoring iteration 24 of 101.
# 25 0.2561298940330744
# Now scoring iteration 25 of 101.
# 26 0.2387617414444685
# Now scoring iteration 26 of 101.
# 27 0.22849819727241993
# Now scoring iteration 27 of 101.
# 28 0.24286129705607892
# Now scoring iteration 28 of 101.
# 29 0.23799649111926555
# Now scoring iteration 29 of 101.
# 30 0.23091986000537873
# Now scoring iteration 30 of 101.
# 31 0.22803468070924282
# Now scoring iteration 31 of 101.
# 32 0.21736950628459453
# Now scoring iteration 32 of 101.
# 33 0.20984393507242202
# Now scoring iteration 33 of 101.
# 34 0.261468520835042
# Now scoring iteration 34 of 101.
# 35 0.24750804848968982
# Now scoring iteration 35 of 101.
# 36 0.26236170396208763
# Now scoring iteration 36 of 101.
# 37 0.2347822741419077
# Now scoring iteration 37 of 101.
# 38 0.22290837094187738
# Now scoring iteration 38 of 101.
# 39 0.2450662837177515
# Now scoring iteration 39 of 101.
# 40 0.20076462492346764
# Now scoring iteration 40 of 101.
# 41 0.2101099566370249
# Now scoring iteration 41 of 101.
# 42 0.22992077752947807
# Now scoring iteration 42 of 101.
# 43 0.22722551964223384
# Now scoring iteration 43 of 101.
# 44 0.19361719101667405
# Now scoring iteration 44 of 101.
# 45 0.21355432830750942
# Now scoring iteration 45 of 101.
# 46 0.20724565230309963
# Now scoring iteration 46 of 101.
# 47 0.23742062389850616
# Now scoring iteration 47 of 101.
# 48 0.2560176498442888
# Now scoring iteration 48 of 101.
# 49 0.21973609186708928
# Now scoring iteration 49 of 101.
# 50 0.20830848351120948
# Now scoring iteration 50 of 101.
# 51 0.23040447175502776
# Now scoring iteration 51 of 101.
# 52 0.22810615576803683
# Now scoring iteration 52 of 101.
# 53 0.21905645705759524
# Now scoring iteration 53 of 101.
# 54 0.22822086207568645
# Now scoring iteration 54 of 101.
# 55 0.22971479073166848
# Now scoring iteration 55 of 101.
# 56 0.21986490920186041
# Now scoring iteration 56 of 101.
# 57 0.22340109787881374
# Now scoring iteration 57 of 101.
# 58 0.22944122061133385
# Now scoring iteration 58 of 101.
# 59 0.22589413061738015
# Now scoring iteration 59 of 101.
# 60 0.20436695970594884
# Now scoring iteration 60 of 101.
# 61 0.22609603680670262
# Now scoring iteration 61 of 101.
# 62 0.21109872072935104
# Now scoring iteration 62 of 101.
# 63 0.22507990293204785
# Now scoring iteration 63 of 101.
# 64 0.23800669729709625
# Now scoring iteration 64 of 101.
# 65 0.2336270309984684
# Now scoring iteration 65 of 101.
# 66 0.24758142456412316
# Now scoring iteration 66 of 101.
# 67 0.2532931250333786
# Now scoring iteration 67 of 101.
# 68 0.21902217477560043
# Now scoring iteration 68 of 101.
# 69 0.232736394777894
# Now scoring iteration 69 of 101.
# 70 0.2240475495159626
# Now scoring iteration 70 of 101.
# 71 0.21307765647768975
# Now scoring iteration 71 of 101.
# 72 0.20360735639929772
# Now scoring iteration 72 of 101.
# 73 0.22666335195302964
# Now scoring iteration 73 of 101.
# 74 0.24329285465180875
# Now scoring iteration 74 of 101.
# 75 0.23666535653173923
# Now scoring iteration 75 of 101.
# 76 0.19642533235251902
# Now scoring iteration 76 of 101.
# 77 0.23380919359624386
# Now scoring iteration 77 of 101.
# 78 0.21955428391695023
# Now scoring iteration 78 of 101.
# 79 0.24369326971471308
# Now scoring iteration 79 of 101.
# 80 0.22747222013771534
# Now scoring iteration 80 of 101.
# 81 0.21952855423092843
# Now scoring iteration 81 of 101.
# 82 0.2369018542021513
# Now scoring iteration 82 of 101.
# 83 0.23240271881222724
# Now scoring iteration 83 of 101.
# 84 0.24746649272739887
# Now scoring iteration 84 of 101.
# 85 0.22128744296729563
# Now scoring iteration 85 of 101.
# 86 0.23775028891861438
# Now scoring iteration 86 of 101.
# 87 0.2115185695886612
# Now scoring iteration 87 of 101.
# 88 0.22026224963366986
# Now scoring iteration 88 of 101.
# 89 0.20949299566447735
# Now scoring iteration 89 of 101.
# 90 0.24595499113202096
# Now scoring iteration 90 of 101.
# 91 0.24994976677000522
# Now scoring iteration 91 of 101.
# 92 0.240259121209383
# Now scoring iteration 92 of 101.
# 93 0.24270743131637573
# Now scoring iteration 93 of 101.
# 94 0.39186124250292775
# Now scoring iteration 94 of 101.
# 95 0.4108848759531975
# Now scoring iteration 95 of 101.
# 96 0.3697845313698053
# Now scoring iteration 96 of 101.
# 97 0.2380837880820036
# Now scoring iteration 97 of 101.
# 98 0.24395283237099646
# Now scoring iteration 98 of 101.
# 99 0.2201264265179634
# Now scoring iteration 99 of 101.
# 100 0.20248856700956822
# Now scoring iteration 100 of 101.
# 101 0.2338559989631176
# Now scoring iteration 101 of 101.
# 102 0.20981376498937607
# Evaluating translation zh-en
# Now scoring iteration 0 of 101.
# 1 0.12780513107776642
# Now scoring iteration 1 of 101.
# 2 0.13114355616271495
# Now scoring iteration 2 of 101.
# 3 0.1280789090692997
# Now scoring iteration 3 of 101.
# 4 0.13024272978305818
# Now scoring iteration 4 of 101.
# 5 0.12729949101805688
# Now scoring iteration 5 of 101.
# 6 0.11818430677056313
# Now scoring iteration 6 of 101.
# 7 0.12658333644270897
# Now scoring iteration 7 of 101.
# 8 0.11964530363678932
# Now scoring iteration 8 of 101.
# 9 0.11478097282350064
# Now scoring iteration 9 of 101.
# 10 0.1228615615516901
# Now scoring iteration 10 of 101.
# 11 0.13106043122708796
# Now scoring iteration 11 of 101.
# 12 0.11799231261014938
# Now scoring iteration 12 of 101.
# 13 0.1200738276541233
# Now scoring iteration 13 of 101.
# 14 0.12915757402777672
# Now scoring iteration 14 of 101.
# 15 0.11275865264236927
# Now scoring iteration 15 of 101.
# 16 0.11516859732568265
# Now scoring iteration 16 of 101.
# 17 0.11608394704759122
# Now scoring iteration 17 of 101.
# 18 0.1278492583334446
# Now scoring iteration 18 of 101.
# 19 0.12594631657004357
# Now scoring iteration 19 of 101.
# 20 0.11521531112492084
# Now scoring iteration 20 of 101.
# 21 0.1104435706883669
# Now scoring iteration 21 of 101.
# 22 0.11925420075654984
# Now scoring iteration 22 of 101.
# 23 0.11327429160475731
# Now scoring iteration 23 of 101.
# 24 0.11640571810305118
# Now scoring iteration 24 of 101.
# 25 0.11667279452085495
# Now scoring iteration 25 of 101.
# 26 0.1113447992503643
# Now scoring iteration 26 of 101.
# 27 0.11828581236302853
# Now scoring iteration 27 of 101.
# 28 0.11461917899549007
# Now scoring iteration 28 of 101.
# 29 0.12229084320366383
# Now scoring iteration 29 of 101.
# 30 0.12508451513946056
# Now scoring iteration 30 of 101.
# 31 0.12285377286374569
# Now scoring iteration 31 of 101.
# 32 0.11952370658516884
# Now scoring iteration 32 of 101.
# 33 0.11341225877404212
# Now scoring iteration 33 of 101.
# 34 0.12854187309741974
# Now scoring iteration 34 of 101.
# 35 0.13250962659716606
# Now scoring iteration 35 of 101.
# 36 0.1323391181975603
# Now scoring iteration 36 of 101.
# 37 0.12697959937155245
# Now scoring iteration 37 of 101.
# 38 0.1263932966440916
# Now scoring iteration 38 of 101.
# 39 0.1321995060145855
# Now scoring iteration 39 of 101.
# 40 0.11644162461161614
# Now scoring iteration 40 of 101.
# 41 0.11424571380019188
# Now scoring iteration 41 of 101.
# 42 0.13092525385320186
# Now scoring iteration 42 of 101.
# 43 0.12545636750757694
# Now scoring iteration 43 of 101.
# 44 0.11503788985311986
# Now scoring iteration 44 of 101.
# 45 0.1335770779848099
# Now scoring iteration 45 of 101.
# 46 0.1183897626399994
# Now scoring iteration 46 of 101.
# 47 0.13185846738517285
# Now scoring iteration 47 of 101.
# 48 0.12675555020570756
# Now scoring iteration 48 of 101.
# 49 0.11990198090672494
# Now scoring iteration 49 of 101.
# 50 0.12390346825122833
# Now scoring iteration 50 of 101.
# 51 0.1261805346608162
# Now scoring iteration 51 of 101.
# 52 0.12319682911038399
# Now scoring iteration 52 of 101.
# 53 0.12630423709750174
# Now scoring iteration 53 of 101.
# 54 0.12839805483818054
# Now scoring iteration 54 of 101.
# 55 0.12011125050485134
# Now scoring iteration 55 of 101.
# 56 0.12693443149328232
# Now scoring iteration 56 of 101.
# 57 0.12207433141767979
# Now scoring iteration 57 of 101.
# 58 0.12576238088309766
# Now scoring iteration 58 of 101.
# 59 0.12646205976605415
# Now scoring iteration 59 of 101.
# 60 0.11971769779920578
# Now scoring iteration 60 of 101.
# 61 0.11758388347923755
# Now scoring iteration 61 of 101.
# 62 0.11953567497432233
# Now scoring iteration 62 of 101.
# 63 0.12254502899944782
# Now scoring iteration 63 of 101.
# 64 0.13589578576385974
# Now scoring iteration 64 of 101.
# 65 0.1281960427761078
# Now scoring iteration 65 of 101.
# 66 0.1241909260302782
# Now scoring iteration 66 of 101.
# 67 0.12992580704391002
# Now scoring iteration 67 of 101.
# 68 0.10833651132881641
# Now scoring iteration 68 of 101.
# 69 0.12808510720729827
# Now scoring iteration 69 of 101.
# 70 0.12727587915956973
# Now scoring iteration 70 of 101.
# 71 0.13044649124145508
# Now scoring iteration 71 of 101.
# 72 0.13252521499991418
# Now scoring iteration 72 of 101.
# 73 0.1346746165305376
# Now scoring iteration 73 of 101.
# 74 0.13465085364878177
# Now scoring iteration 74 of 101.
# 75 0.12644975751638413
# Now scoring iteration 75 of 101.
# 76 0.11894460961222648
# Now scoring iteration 76 of 101.
# 77 0.12165559165179729
# Now scoring iteration 77 of 101.
# 78 0.12996266938745976
# Now scoring iteration 78 of 101.
# 79 0.1344348831474781
# Now scoring iteration 79 of 101.
# 80 0.116387387663126
# Now scoring iteration 80 of 101.
# 81 0.12249730050563812
# Now scoring iteration 81 of 101.
# 82 0.10916550144553185
# Now scoring iteration 82 of 101.
# 83 0.11217983223497868
# Now scoring iteration 83 of 101.
# 84 0.13502555035054684
# Now scoring iteration 84 of 101.
# 85 0.1345373197644949
# Now scoring iteration 85 of 101.
# 86 0.12164160214364529
# Now scoring iteration 86 of 101.
# 87 0.11465894199907779
# Now scoring iteration 87 of 101.
# 88 0.12312819845974446
# Now scoring iteration 88 of 101.
# 89 0.11788082607090473
# Now scoring iteration 89 of 101.
# 90 0.1262187321484089
# Now scoring iteration 90 of 101.
# 91 0.12992982394993305
# Now scoring iteration 91 of 101.
# 92 0.12026569284498692
# Now scoring iteration 92 of 101.
# 93 0.1316383808851242
# Now scoring iteration 93 of 101.
# 94 0.36359699830412867
# Now scoring iteration 94 of 101.
# 95 0.36652507990598676
# Now scoring iteration 95 of 101.
# 96 0.33052769020199774
# Now scoring iteration 96 of 101.
# 97 0.1264956623315811
# Now scoring iteration 97 of 101.
# 98 0.13495706520974637
# Now scoring iteration 98 of 101.
# 99 0.11666222952306271
# Now scoring iteration 99 of 101.
# 100 0.1214589585363865
# Now scoring iteration 100 of 101.
# 101 0.1307108264416456
# Now scoring iteration 101 of 101.
# 102 0.12664458721876146
# Evaluating translation en-es
# Now scoring iteration 0 of 101.
# 1 0.10308834679424762
# Now scoring iteration 1 of 101.
# 2 0.1014073583483696
# Now scoring iteration 2 of 101.
# 3 0.1004086747020483
# Now scoring iteration 3 of 101.
# 4 0.09750452540814876
# Now scoring iteration 4 of 101.
# 5 0.09323304653167724
# Now scoring iteration 5 of 101.
# 6 0.09795219630002976
# Now scoring iteration 6 of 101.
# 7 0.09739667497575283
# Now scoring iteration 7 of 101.
# 8 0.09657017655670642
# Now scoring iteration 8 of 101.
# 9 0.09540223404765129
# Now scoring iteration 9 of 101.
# 10 0.10139178119599819
# Now scoring iteration 10 of 101.
# 11 0.15694334872066976
# Now scoring iteration 11 of 101.
# 12 0.10502998255193234
# Now scoring iteration 12 of 101.
# 13 0.10057192720472813
# Now scoring iteration 13 of 101.
# 14 0.10751045331358909
# Now scoring iteration 14 of 101.
# 15 0.09415591262280941
# Now scoring iteration 15 of 101.
# 16 0.11023912355303764
# Now scoring iteration 16 of 101.
# 17 0.11455474115908146
# Now scoring iteration 17 of 101.
# 18 0.1053723669797182
# Now scoring iteration 18 of 101.
# 19 0.11850944764912129
# Now scoring iteration 19 of 101.
# 20 0.11153011791408061
# Now scoring iteration 20 of 101.
# 21 0.08208945281803608
# Now scoring iteration 21 of 101.
# 22 0.09217552810907365
# Now scoring iteration 22 of 101.
# 23 0.10861679024994374
# Now scoring iteration 23 of 101.
# 24 0.09772550567984581
# Now scoring iteration 24 of 101.
# 25 0.10200821325182914
# Now scoring iteration 25 of 101.
# 26 0.10386310644447803
# Now scoring iteration 26 of 101.
# 27 0.09439180299639702
# Now scoring iteration 27 of 101.
# 28 0.09780758820474147
# Now scoring iteration 28 of 101.
# 29 0.0955522195249796
# Now scoring iteration 29 of 101.
# 30 0.10478907987475396
# Now scoring iteration 30 of 101.
# 31 0.09695222541689873
# Now scoring iteration 31 of 101.
# 32 0.09629344746470452
# Now scoring iteration 32 of 101.
# 33 0.08864627152681351
# Now scoring iteration 33 of 101.
# 34 0.08998061954975128
# Now scoring iteration 34 of 101.
# 35 0.09936424233019352
# Now scoring iteration 35 of 101.
# 36 0.10207256712019444
# Now scoring iteration 36 of 101.
# 37 0.11765207707881928
# Now scoring iteration 37 of 101.
# 38 0.10613339178264142
# Now scoring iteration 38 of 101.
# 39 0.12702929481863975
# Now scoring iteration 39 of 101.
# 40 0.11028592199087144
# Now scoring iteration 40 of 101.
# 41 0.10013292625546455
# Now scoring iteration 41 of 101.
# 42 0.11036861434578896
# Now scoring iteration 42 of 101.
# 43 0.11335055582225323
# Now scoring iteration 43 of 101.
# 44 0.09885641843080521
# Now scoring iteration 44 of 101.
# 45 0.09186152711510659
# Now scoring iteration 45 of 101.
# 46 0.11036916971206664
# Now scoring iteration 46 of 101.
# 47 0.10321659773588181
# Now scoring iteration 47 of 101.
# 48 0.10295235842466355
# Now scoring iteration 48 of 101.
# 49 0.10470573633909225
# Now scoring iteration 49 of 101.
# 50 0.10027673281729221
# Now scoring iteration 50 of 101.
# 51 0.09847249411046505
# Now scoring iteration 51 of 101.
# 52 0.09520711787045003
# Now scoring iteration 52 of 101.
# 53 0.10107792817056178
# Now scoring iteration 53 of 101.
# 54 0.10572888366878033
# Now scoring iteration 54 of 101.
# 55 0.11746781088411808
# Now scoring iteration 55 of 101.
# 56 0.10370584711432457
# Now scoring iteration 56 of 101.
# 57 0.10371278241276741
# Now scoring iteration 57 of 101.
# 58 0.09167742483317852
# Now scoring iteration 58 of 101.
# 59 0.10212588809430599
# Now scoring iteration 59 of 101.
# 60 0.08755001455545425
# Now scoring iteration 60 of 101.
# 61 0.09881320603191852
# Now scoring iteration 61 of 101.
# 62 0.09881126165390014
# Now scoring iteration 62 of 101.
# 63 0.10072515524923802
# Now scoring iteration 63 of 101.
# 64 0.10353345423936844
# Now scoring iteration 64 of 101.
# 65 0.10752307087182998
# Now scoring iteration 65 of 101.
# 66 0.08921732500195503
# Now scoring iteration 66 of 101.
# 67 0.09673563674092293
# Now scoring iteration 67 of 101.
# 68 0.1036202847957611
# Now scoring iteration 68 of 101.
# 69 0.08131850346922874
# Now scoring iteration 69 of 101.
# 70 0.10186747804284096
# Now scoring iteration 70 of 101.
# 71 0.1062966974079609
# Now scoring iteration 71 of 101.
# 72 0.09043464615941048
# Now scoring iteration 72 of 101.
# 73 0.10452952533960343
# Now scoring iteration 73 of 101.
# 74 0.0928741841763258
# Now scoring iteration 74 of 101.
# 75 0.09441797114908695
# Now scoring iteration 75 of 101.
# 76 0.08795163720846176
# Now scoring iteration 76 of 101.
# 77 0.0903873410075903
# Now scoring iteration 77 of 101.
# 78 0.09856941990554333
# Now scoring iteration 78 of 101.
# 79 0.0811634237319231
# Now scoring iteration 79 of 101.
# 80 0.09519325457513332
# Now scoring iteration 80 of 101.
# 81 0.08848648838698864
# Now scoring iteration 81 of 101.
# 82 0.10945997901260852
# Now scoring iteration 82 of 101.
# 83 0.10584211230278015
# Now scoring iteration 83 of 101.
# 84 0.09559360973536968
# Now scoring iteration 84 of 101.
# 85 0.07914700359106064
# Now scoring iteration 85 of 101.
# 86 0.10426293209195137
# Now scoring iteration 86 of 101.
# 87 0.09419403240084648
# Now scoring iteration 87 of 101.
# 88 0.1035149035602808
# Now scoring iteration 88 of 101.
# 89 0.094629672691226
# Now scoring iteration 89 of 101.
# 90 0.09401467487215996
# Now scoring iteration 90 of 101.
# 91 0.10575938530266285
# Now scoring iteration 91 of 101.
# 92 0.10160875260829925
# Now scoring iteration 92 of 101.
# 93 0.09833276957273483
# Now scoring iteration 93 of 101.
# 94 0.10212233573198319
# Now scoring iteration 94 of 101.
# 95 0.11397423781454563
# Now scoring iteration 95 of 101.
# 96 0.09569708727300168
# Now scoring iteration 96 of 101.
# 97 0.11534138172864913
# Now scoring iteration 97 of 101.
# 98 0.10070827923715114
# Now scoring iteration 98 of 101.
# 99 0.09242178857326508
# Now scoring iteration 99 of 101.
# 100 0.11873947106301784
# Now scoring iteration 100 of 101.
# 101 0.09967246480286121
# Now scoring iteration 101 of 101.
# 102 0.0884645077586174
# Evaluating translation es-zh
# Now scoring iteration 0 of 51.
# 1 0.23965426795184613
# Now scoring iteration 1 of 51.
# 2 0.2124090314656496
# Now scoring iteration 2 of 51.
# 3 0.24241705000400543
# Now scoring iteration 3 of 51.
# 4 0.24940544188022615
# Now scoring iteration 4 of 51.
# 5 0.2740048847347498
# Now scoring iteration 5 of 51.
# 6 0.2330073669552803
# Now scoring iteration 6 of 51.
# 7 0.24417360745370387
# Now scoring iteration 7 of 51.
# 8 0.2368232723325491
# Now scoring iteration 8 of 51.
# 9 0.2128547754883766
# Now scoring iteration 9 of 51.
# 10 0.23555762603878974
# Now scoring iteration 10 of 51.
# 11 0.2362301179766655
# Now scoring iteration 11 of 51.
# 12 0.22604106813669206
# Now scoring iteration 12 of 51.
# 13 0.24467855386435985
# Now scoring iteration 13 of 51.
# 14 0.25614853218197825
# Now scoring iteration 14 of 51.
# 15 0.20738256663084031
# Now scoring iteration 15 of 51.
# 16 0.21274546250700951
# Now scoring iteration 16 of 51.
# 17 0.23230607628822328
# Now scoring iteration 17 of 51.
# 18 0.25521921992301944
# Now scoring iteration 18 of 51.
# 19 0.24367460556328296
# Now scoring iteration 19 of 51.
# 20 0.22678251221776008
# Now scoring iteration 20 of 51.
# 21 0.23999392606317996
# Now scoring iteration 21 of 51.
# 22 0.23069253742694854
# Now scoring iteration 22 of 51.
# 23 0.2263352979719639
# Now scoring iteration 23 of 51.
# 24 0.2450997619330883
# Now scoring iteration 24 of 51.
# 25 0.22781551383435727
# Now scoring iteration 25 of 51.
# 26 0.2324865408241749
# Now scoring iteration 26 of 51.
# 27 0.2535057087242603
# Now scoring iteration 27 of 51.
# 28 0.2708599966019392
# Now scoring iteration 28 of 51.
# 29 0.2410031060874462
# Now scoring iteration 29 of 51.
# 30 0.23405169278383256
# Now scoring iteration 30 of 51.
# 31 0.23436495535075663
# Now scoring iteration 31 of 51.
# 32 0.21020556919276714
# Now scoring iteration 32 of 51.
# 33 0.2622961886972189
# Now scoring iteration 33 of 51.
# 34 0.25783163800835607
# Now scoring iteration 34 of 51.
# 35 0.26168944239616393
# Now scoring iteration 35 of 51.
# 36 0.23461687907576562
# Now scoring iteration 36 of 51.
# 37 0.235232025757432
# Now scoring iteration 37 of 51.
# 38 0.24206405460834504
# Now scoring iteration 38 of 51.
# 39 0.22998268514871598
# Now scoring iteration 39 of 51.
# 40 0.23015437602996827
# Now scoring iteration 40 of 51.
# 41 0.24232615880668162
# Now scoring iteration 41 of 51.
# 42 0.22279800057411195
# Now scoring iteration 42 of 51.
# 43 0.2288424239307642
# Now scoring iteration 43 of 51.
# 44 0.24927392907440662
# Now scoring iteration 44 of 51.
# 45 0.23670364513993264
# Now scoring iteration 45 of 51.
# 46 0.2539294981211424
# Now scoring iteration 46 of 51.
# 47 0.21029599145054817
# Now scoring iteration 47 of 51.
# 48 0.23017939135432244
# Now scoring iteration 48 of 51.
# 49 0.26184495851397516
# Now scoring iteration 49 of 51.
# 50 0.22546044759452344
# Now scoring iteration 50 of 51.
# 51 0.23586015127599239
# Now scoring iteration 51 of 51.
# 52 0.25173911176621916
# Evaluating translation es-en
# Now scoring iteration 0 of 101.
# 1 0.17381835378706456
# Now scoring iteration 1 of 101.
# 2 0.15640462540090083
# Now scoring iteration 2 of 101.
# 3 0.1750692656636238
# Now scoring iteration 3 of 101.
# 4 0.1646125426888466
# Now scoring iteration 4 of 101.
# 5 0.17233449526131153
# Now scoring iteration 5 of 101.
# 6 0.16014190644025803
# Now scoring iteration 6 of 101.
# 7 0.16507636301219464
# Now scoring iteration 7 of 101.
# 8 0.1731870698183775
# Now scoring iteration 8 of 101.
# 9 0.15959450505673886
# Now scoring iteration 9 of 101.
# 10 0.17419951237738132
# Now scoring iteration 10 of 101.
# 11 0.2076048519462347
# Now scoring iteration 11 of 101.
# 12 0.17908769384026527
# Now scoring iteration 12 of 101.
# 13 0.1675522967427969
# Now scoring iteration 13 of 101.
# 14 0.18674600191414356
# Now scoring iteration 14 of 101.
# 15 0.1606615349650383
# Now scoring iteration 15 of 101.
# 16 0.1741319078207016
# Now scoring iteration 16 of 101.
# 17 0.18257788076996803
# Now scoring iteration 17 of 101.
# 18 0.18108158320188522
# Now scoring iteration 18 of 101.
# 19 0.17610985025763512
# Now scoring iteration 19 of 101.
# 20 0.1810341689735651
# Now scoring iteration 20 of 101.
# 21 0.15443436190485954
# Now scoring iteration 21 of 101.
# 22 0.16527421481907367
# Now scoring iteration 22 of 101.
# 23 0.18345021910965442
# Now scoring iteration 23 of 101.
# 24 0.18383910872042178
# Now scoring iteration 24 of 101.
# 25 0.1667525152862072
# Now scoring iteration 25 of 101.
# 26 0.15896430671215056
# Now scoring iteration 26 of 101.
# 27 0.16709492221474648
# Now scoring iteration 27 of 101.
# 28 0.18171690955758094
# Now scoring iteration 28 of 101.
# 29 0.16471714824438094
# Now scoring iteration 29 of 101.
# 30 0.1742879492789507
# Now scoring iteration 30 of 101.
# 31 0.16212323054671288
# Now scoring iteration 31 of 101.
# 32 0.15844040051102637
# Now scoring iteration 32 of 101.
# 33 0.14792460486292838
# Now scoring iteration 33 of 101.
# 34 0.14950492717325686
# Now scoring iteration 34 of 101.
# 35 0.17155962608754635
# Now scoring iteration 35 of 101.
# 36 0.16667163483798503
# Now scoring iteration 36 of 101.
# 37 0.19056606248021127
# Now scoring iteration 37 of 101.
# 38 0.1754976512491703
# Now scoring iteration 38 of 101.
# 39 0.1860006158053875
# Now scoring iteration 39 of 101.
# 40 0.16918649211525916
# Now scoring iteration 40 of 101.
# 41 0.16414589546620845
# Now scoring iteration 41 of 101.
# 42 0.18378338307142258
# Now scoring iteration 42 of 101.
# 43 0.18041971378028393
# Now scoring iteration 43 of 101.
# 44 0.1787804128974676
# Now scoring iteration 44 of 101.
# 45 0.1503994330018759
# Now scoring iteration 45 of 101.
# 46 0.17809880182147025
# Now scoring iteration 46 of 101.
# 47 0.1741690944880247
# Now scoring iteration 47 of 101.
# 48 0.17479231335222722
# Now scoring iteration 48 of 101.
# 49 0.18249844133853912
# Now scoring iteration 49 of 101.
# 50 0.16743136525154115
# Now scoring iteration 50 of 101.
# 51 0.17813178166747093
# Now scoring iteration 51 of 101.
# 52 0.18321951270103454
# Now scoring iteration 52 of 101.
# 53 0.16040506109595298
# Now scoring iteration 53 of 101.
# 54 0.16525978200137614
# Now scoring iteration 54 of 101.
# 55 0.19499740965664386
# Now scoring iteration 55 of 101.
# 56 0.16996136017143726
# Now scoring iteration 56 of 101.
# 57 0.1808112684637308
# Now scoring iteration 57 of 101.
# 58 0.1539290115237236
# Now scoring iteration 58 of 101.
# 59 0.1778800106048584
# Now scoring iteration 59 of 101.
# 60 0.15644995480775833
# Now scoring iteration 60 of 101.
# 61 0.15936392322182655
# Now scoring iteration 61 of 101.
# 62 0.1649875471740961
# Now scoring iteration 62 of 101.
# 63 0.1531186880916357
# Now scoring iteration 63 of 101.
# 64 0.17685723289847374
# Now scoring iteration 64 of 101.
# 65 0.1751882704347372
# Now scoring iteration 65 of 101.
# 66 0.16924210548400878
# Now scoring iteration 66 of 101.
# 67 0.16712408371269702
# Now scoring iteration 67 of 101.
# 68 0.18447415679693221
# Now scoring iteration 68 of 101.
# 69 0.1515880124270916
# Now scoring iteration 69 of 101.
# 70 0.1717575804889202
# Now scoring iteration 70 of 101.
# 71 0.1733940076082945
# Now scoring iteration 71 of 101.
# 72 0.15387787461280822
# Now scoring iteration 72 of 101.
# 73 0.18420106098055838
# Now scoring iteration 73 of 101.
# 74 0.17052630320191384
# Now scoring iteration 74 of 101.
# 75 0.1561227274686098
# Now scoring iteration 75 of 101.
# 76 0.14981410384178162
# Now scoring iteration 76 of 101.
# 77 0.14297253891825676
# Now scoring iteration 77 of 101.
# 78 0.16284972347319127
# Now scoring iteration 78 of 101.
# 79 0.155423037186265
# Now scoring iteration 79 of 101.
# 80 0.16321151137351989
# Now scoring iteration 80 of 101.
# 81 0.16652020812034607
# Now scoring iteration 81 of 101.
# 82 0.17475835487246513
# Now scoring iteration 82 of 101.
# 83 0.16432228215038777
# Now scoring iteration 83 of 101.
# 84 0.1747528824210167
# Now scoring iteration 84 of 101.
# 85 0.14811219833791256
# Now scoring iteration 85 of 101.
# 86 0.18111704401671885
# Now scoring iteration 86 of 101.
# 87 0.15956928938627243
# Now scoring iteration 87 of 101.
# 88 0.16724467001855373
# Now scoring iteration 88 of 101.
# 89 0.15460340335965156
# Now scoring iteration 89 of 101.
# 90 0.15307918697595596
# Now scoring iteration 90 of 101.
# 91 0.16332464873790742
# Now scoring iteration 91 of 101.
# 92 0.16660350002348423
# Now scoring iteration 92 of 101.
# 93 0.1699776142090559
# Now scoring iteration 93 of 101.
# 94 0.15297153450548648
# Now scoring iteration 94 of 101.
# 95 0.17382582016289233
# Now scoring iteration 95 of 101.
# 96 0.16055779300630094
# Now scoring iteration 96 of 101.
# 97 0.1771410468965769
# Now scoring iteration 97 of 101.
# 98 0.17415439166128635
# Now scoring iteration 98 of 101.
# 99 0.16708540879189968
# Now scoring iteration 99 of 101.
# 100 0.17959882162511348
# Now scoring iteration 100 of 101.
# 101 0.16178696744143964
# Now scoring iteration 101 of 101.
# 102 0.16348410569131375
# Evaluating translation zh-es
# Now scoring iteration 0 of 51.
# 1 0.08280267618596554
# Now scoring iteration 1 of 51.
# 2 0.07327575474977494
# Now scoring iteration 2 of 51.
# 3 0.08119041793048382
# Now scoring iteration 3 of 51.
# 4 0.08547903530299664
# Now scoring iteration 4 of 51.
# 5 0.09252409778535366
# Now scoring iteration 5 of 51.
# 6 0.07113506659865379
# Now scoring iteration 6 of 51.
# 7 0.07646898634731769
# Now scoring iteration 7 of 51.
# 8 0.07522662431001663
# Now scoring iteration 8 of 51.
# 9 0.07075130850076676
# Now scoring iteration 9 of 51.
# 10 0.08655612535774708
# Now scoring iteration 10 of 51.
# 11 0.0857858545333147
# Now scoring iteration 11 of 51.
# 12 0.07758027009665966
# Now scoring iteration 12 of 51.
# 13 0.0746404604613781
# Now scoring iteration 13 of 51.
# 14 0.08128288432955742
# Now scoring iteration 14 of 51.
# 15 0.06984104849398136
# Now scoring iteration 15 of 51.
# 16 0.07619485333561897
# Now scoring iteration 16 of 51.
# 17 0.08765468418598175
# Now scoring iteration 17 of 51.
# 18 0.07864588007330894
# Now scoring iteration 18 of 51.
# 19 0.08117971390485763
# Now scoring iteration 19 of 51.
# 20 0.06894442170858384
# Now scoring iteration 20 of 51.
# 21 0.0780359997600317
# Now scoring iteration 21 of 51.
# 22 0.0728271897137165
# Now scoring iteration 22 of 51.
# 23 0.0663852782547474
# Now scoring iteration 23 of 51.
# 24 0.07836012326180936
# Now scoring iteration 24 of 51.
# 25 0.07057780392467976
# Now scoring iteration 25 of 51.
# 26 0.07160005524754524
# Now scoring iteration 26 of 51.
# 27 0.07740789860486984
# Now scoring iteration 27 of 51.
# 28 0.0869252187013626
# Now scoring iteration 28 of 51.
# 29 0.08275573551654816
# Now scoring iteration 29 of 51.
# 30 0.07445844061672688
# Now scoring iteration 30 of 51.
# 31 0.07693962752819061
# Now scoring iteration 31 of 51.
# 32 0.06831551223993301
# Now scoring iteration 32 of 51.
# 33 0.09437184251844882
# Now scoring iteration 33 of 51.
# 34 0.08204872950911522
# Now scoring iteration 34 of 51.
# 35 0.08992907389998436
# Now scoring iteration 35 of 51.
# 36 0.07689212523400783
# Now scoring iteration 36 of 51.
# 37 0.07675173729658127
# Now scoring iteration 37 of 51.
# 38 0.07986980117857456
# Now scoring iteration 38 of 51.
# 39 0.06342163287103177
# Now scoring iteration 39 of 51.
# 40 0.07412009947001934
# Now scoring iteration 40 of 51.
# 41 0.07999981239438057
# Now scoring iteration 41 of 51.
# 42 0.07758414141833782
# Now scoring iteration 42 of 51.
# 43 0.0805775310099125
# Now scoring iteration 43 of 51.
# 44 0.08464906707406045
# Now scoring iteration 44 of 51.
# 45 0.08325262099504471
# Now scoring iteration 45 of 51.
# 46 0.08533886626362801
# Now scoring iteration 46 of 51.
# 47 0.07034827746450902
# Now scoring iteration 47 of 51.
# 48 0.07445696331560611
# Now scoring iteration 48 of 51.
# 49 0.08440423890948295
# Now scoring iteration 49 of 51.
# 50 0.07903894774615765
# Now scoring iteration 50 of 51.
# 51 0.07654354877769948
# Now scoring iteration 51 of 51.
# 52 0.08804999992251396

# %%
# !ls
